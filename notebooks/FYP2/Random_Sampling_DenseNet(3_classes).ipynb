# %% [markdown]
# <a href="https://colab.research.google.com/github/muhdlaziem/DR/blob/master/Random_Sampling_DenseNet(3_classes).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/'My Drive'/
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
nr_seed = 2019
import numpy as np 
np.random.seed(nr_seed)
import tensorflow as tf
tf.set_random_seed(nr_seed)
print(tf.__version__)
# Out:
# 1.15.2

# %%
# import libraries
import json
import math
from tqdm import tqdm, tqdm_notebook
import gc
import warnings
import os

import cv2
from PIL import Image

import pandas as pd
import scipy
import matplotlib.pyplot as plt

from keras import backend as K
from keras import layers
from keras.applications.densenet import DenseNet121
from keras.callbacks import Callback, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score

warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# Image size
im_size = 320
# Batch size
BATCH_SIZE = 20

# %% [markdown]
# # Loading

# %%
# %cd diabetic-retinopathy-resized/
DR = pd.read_csv('5_3_2_levels.csv')
DR.head()
# Out:
# /gdrive/My Drive/diabetic-retinopathy-resized
#            image  level  level(3)  level(2)
# 0   10_left.jpeg      0         0         0
# 1  10_right.jpeg      0         0         0
# 2   13_left.jpeg      0         0         0
# 3  13_right.jpeg      0         0         0
# 4   15_left.jpeg      1         1         1

# %%
DR = DR.sample(15000)

# %%
DR['level(3)'].value_counts()
# Out:
# 0    11052
# 1     3262
# 2      686
# Name: level(3), dtype: int64

# %% [markdown]
# ## Under Sampling

# %%
# index_0 = DR[DR['level']==0].sample(25802-800).index
# index_1 = DR[DR['level']==1].sample(2438-753).index
# index_2 = DR[DR['level']==2].sample(5288-739).index
# index_3 = DR[DR['level']==3].sample(872-710).index
# index_4 = DR[DR['level']==4].sample(708-708).index

# undersampling_DR = DR.drop(index_0)
# undersampling_DR = undersampling_DR.drop(index_1)
# undersampling_DR = undersampling_DR.drop(index_2)
# undersampling_DR = undersampling_DR.drop(index_3)
# undersampling_DR = undersampling_DR.drop(index_4)

# undersampling_DR['level'].value_counts()

# %% [markdown]
# ## Train - Valid split

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(DR,test_size=0.30, random_state=42)

# %%
# Let's shuffle the datasets
train_df = train_df.sample(frac=1).reset_index(drop=True)
val_df = val_df.sample(frac=1).reset_index(drop=True)
print(train_df.shape)
print(val_df.shape)
# Out:
# (10500, 4)
# (4500, 4)

# %% [markdown]
# ## Process Images

# %% [markdown]
# Crop function: https://www.kaggle.com/ratthachat/aptos-updated-preprocessing-ben-s-cropping

# %%
def preprocess_image(image_path, desired_size=224):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #img = crop_image_from_gray(img)
    img = cv2.resize(img, (desired_size,desired_size))
    img = cv2.addWeighted(img,4,cv2.GaussianBlur(img, (0,0), desired_size/40) ,-4 ,128)
    
    return img

# %%
# %cd /gdrive/My Drive/diabetic-retinopathy-resized/resized_train_cropped/resized_train_cropped
def display_samples(df, columns=4, rows=3):
    fig=plt.figure(figsize=(5*columns, 4*rows))

    for i in range(columns*rows):
        image_path = df.loc[i,'image']
        image_id = df.loc[i,'level(3)']
        img = cv2.imread(f'{image_path}')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        #img = crop_image_from_gray(img)
        img = cv2.resize(img, (im_size,im_size))
        img = cv2.addWeighted(img,4,cv2.GaussianBlur(img, (0,0), im_size/40) ,-4 ,128)
        
        fig.add_subplot(rows, columns, i+1)
        plt.title(image_id)
        plt.imshow(img)
    
    plt.tight_layout()

display_samples(train_df)
# Out:
# /gdrive/My Drive/diabetic-retinopathy-resized/resized_train_cropped/resized_train_cropped

# %% [markdown]
# # Processing Images

# %% [markdown]
# __UPDATE:__ Here we are reading just the validation set. In order to use 320x320 images, we are going to load one bucket at a time only when needed. This will let our code run without memory-related errors.

# %%
# validation set
N = val_df.shape[0]
x_val = np.empty((N, im_size, im_size, 3), dtype=np.uint8)

for i, image_id in enumerate(tqdm_notebook(val_df['image'])):
    x_val[i, :, :, :] = preprocess_image(
        f'{image_id}',
        desired_size = im_size
    )
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4500.0), HTML(value='')))

# %%
y_train = pd.get_dummies(train_df['level(3)']).values
y_val = pd.get_dummies(val_df['level(3)']).values

print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (10500, 3)
# (4500, 320, 320, 3)
# (4500, 3)

# %% [markdown]
# # Creating multilabels
#
# Instead of predicting a single label, we will change our target to be a multilabel problem; i.e., if the target is a certain class, then it encompasses all the classes before it. E.g. encoding a class 4 retinopathy would usually be `[0, 0, 0, 1]`, but in our case we will predict `[1, 1, 1, 1]`. For more details, please check out [Lex's kernel](https://www.kaggle.com/lextoumbourou/blindness-detection-resnet34-ordinal-targets).

# %%
y_train_multi = np.empty(y_train.shape, dtype=y_train.dtype)
y_train_multi[:, 2] = y_train[:, 2]

for i in range(1, -1, -1):
    y_train_multi[:, i] = np.logical_or(y_train[:, i], y_train_multi[:, i+1])

y_val_multi = np.empty(y_val.shape, dtype=y_val.dtype)
y_val_multi[:, 2] = y_val[:, 2]

for i in range(1, -1, -1):
    y_val_multi[:, i] = np.logical_or(y_val[:, i], y_val_multi[:, i+1])

print("Y_train multi: {}".format(y_train_multi.shape))
print("Y_val multi: {}".format(y_val_multi.shape))
# Out:
# Y_train multi: (10500, 3)
# Y_val multi: (4500, 3)

# %%
y_train = y_train_multi
y_val = y_val_multi

# %% [markdown]
# # Creating keras callback for QWK
#
# ---
#
# I had to change this function, in order to consider the best kappa score among all the buckets.

# %%
class Metrics(Callback):

    def on_epoch_end(self, epoch, logs={}):
        X_val, y_val = self.validation_data[:2]
        y_val = y_val.sum(axis=1) - 1
        
        y_pred = self.model.predict(X_val) > 0.5
        y_pred = y_pred.astype(int).sum(axis=1) - 1

        _val_kappa = cohen_kappa_score(
            y_val,
            y_pred, 
            weights='quadratic'
        )

        self.val_kappas.append(_val_kappa)

        print(f"val_kappa: {_val_kappa:.4f}")
        
        if _val_kappa == max(self.val_kappas):
            print("Validation Kappa has improved. Saving model.")
            self.model.save('denseNet_3_all.h5')

        return

# %% [markdown]
# # Data Generator

# %%
def create_datagen():
    return ImageDataGenerator(
        featurewise_std_normalization = True,
        horizontal_flip = True,
        vertical_flip = True,
        rotation_range = 360
    )

# %% [markdown]
# # Model: DenseNet-121

# %%
densenet = DenseNet121(
    weights='/gdrive/My Drive/DenseNet-BC-121-32-no-top.h5',
    include_top=False,
    input_shape=(im_size,im_size,3)
)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
def build_model():
    model = Sequential()
    model.add(densenet)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(3, activation='sigmoid'))
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=0.0001,decay=1e-6),
        metrics=['accuracy']
    )
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 10, 10, 1024)      7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 7,040,579
# Trainable params: 6,956,931
# Non-trainable params: 83,648
# _________________________________________________________________

# %% [markdown]
# # Training & Evaluation

# %%
#train_df = train_df.reset_index(drop=True)
bucket_num = 8
# bucket_num = 3
div = round(train_df.shape[0]/bucket_num)

# %%
df_init = {
    'val_loss': [0.0],
    'val_accuracy': [0.0],
    'loss': [0.0], 
    'accuracy': [0.0],
    'bucket': [0.0]
}
results = pd.DataFrame(df_init)

# %%
# I found that changing the nr. of epochs for each bucket helped in terms of performances
epochs = [5,5,10,15,15,20,20,30]
# epochs = [5,5,10]
kappa_metrics = Metrics()
kappa_metrics.val_kappas = []

# %%
for i in range(0,bucket_num):
    if i != (bucket_num-1):
        print("Bucket Nr: {}".format(i))
        
        N = train_df.iloc[i*div:(1+i)*div].shape[0]
        x_train = np.empty((N, im_size, im_size, 3), dtype=np.uint8)
        for j, image_id in enumerate(tqdm_notebook(train_df.iloc[i*div:(1+i)*div,0])):
            x_train[j, :, :, :] = preprocess_image(f'{image_id}', desired_size = im_size)

        data_generator = create_datagen().flow(x_train, y_train[i*div:(1+i)*div,:], batch_size=BATCH_SIZE)
        history = model.fit_generator(
                        data_generator,
                        steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
                        epochs=epochs[i],
                        validation_data=(x_val, y_val),
                        callbacks=[kappa_metrics]
                        )
        
        dic = history.history
        df_model = pd.DataFrame(dic)
        df_model['bucket'] = i
    else:
        print("Bucket Nr: {}".format(i))
        
        N = train_df.iloc[i*div:].shape[0]
        x_train = np.empty((N, im_size, im_size, 3), dtype=np.uint8)
        for j, image_id in enumerate(tqdm_notebook(train_df.iloc[i*div:,0])):
            x_train[j, :, :, :] = preprocess_image(f'{image_id}', desired_size = im_size)
        data_generator = create_datagen().flow(x_train, y_train[i*div:,:], batch_size=BATCH_SIZE)
        
        history = model.fit_generator(
                        data_generator,
                        steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
                        epochs=epochs[i],
                        validation_data=(x_val, y_val),
                        callbacks=[kappa_metrics]
                        )
        
        dic = history.history
        df_model = pd.DataFrame(dic)
        df_model['bucket'] = i

    results = results.append(df_model)
    
    del data_generator
    del x_train
    gc.collect()
    
    print('-'*40)
# Out:
# Bucket Nr: 0
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/5
# 66/65 [==============================] - 120s 2s/step - loss: 0.4715 - accuracy: 0.7929 - val_loss: 1.1260 - val_accuracy: 0.3767
# val_kappa: 0.1295
# Validation Kappa has improved. Saving model.
# Epoch 2/5
# 66/65 [==============================] - 76s 1s/step - loss: 0.2556 - accuracy: 0.8968 - val_loss: 0.3400 - val_accuracy: 0.8969
# val_kappa: 0.4241
# Validation Kappa has improved. Saving model.
# Epoch 3/5
# 66/65 [==============================] - 76s 1s/step - loss: 0.2329 - accuracy: 0.9014 - val_loss: 0.2408 - val_accuracy: 0.9162
# val_kappa: 0.5103
# Validation Kappa has improved. Saving model.
# Epoch 4/5
# 66/65 [==============================] - 75s 1s/step - loss: 0.2094 - accuracy: 0.9151 - val_loss: 0.2427 - val_accuracy: 0.8898
# val_kappa: 0.4349
# Epoch 5/5
# 66/65 [==============================] - 75s 1s/step - loss: 0.2047 - accuracy: 0.9157 - val_loss: 0.2204 - val_accuracy: 0.9149
# val_kappa: 0.3475
# ----------------------------------------
# Bucket Nr: 1
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/5
# 66/65 [==============================] - 80s 1s/step - loss: 0.2098 - accuracy: 0.9157 - val_loss: 0.2611 - val_accuracy: 0.9096
# val_kappa: 0.2499
# Epoch 2/5
# 66/65 [==============================] - 76s 1s/step - loss: 0.1994 - accuracy: 0.9200 - val_loss: 0.1821 - val_accuracy: 0.9256
# val_kappa: 0.4954
# Epoch 3/5
# 66/65 [==============================] - 77s 1s/step - loss: 0.1835 - accuracy: 0.9251 - val_loss: 0.1753 - val_accuracy: 0.9305
# val_kappa: 0.5586
# Validation Kappa has improved. Saving model.
# Epoch 4/5
# 66/65 [==============================] - 76s 1s/step - loss: 0.1588 - accuracy: 0.9345 - val_loss: 0.2040 - val_accuracy: 0.9222
# val_kappa: 0.4197
# Epoch 5/5
# 66/65 [==============================] - 76s 1s/step - loss: 0.1616 - accuracy: 0.9347 - val_loss: 0.1984 - val_accuracy: 0.9168
# val_kappa: 0.4656
# ----------------------------------------
# Bucket Nr: 2
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/10
# 66/65 [==============================] - 81s 1s/step - loss: 0.1914 - accuracy: 0.9258 - val_loss: 0.1802 - val_accuracy: 0.9304
# val_kappa: 0.5515
# Epoch 2/10
# 66/65 [==============================] - 76s 1s/step - loss: 0.1816 - accuracy: 0.9258 - val_loss: 0.2113 - val_accuracy: 0.9275
# val_kappa: 0.4903
# Epoch 3/10
# 66/65 [==============================] - 76s 1s/step - loss: 0.1638 - accuracy: 0.9317 - val_loss: 0.2020 - val_accuracy: 0.9278
# val_kappa: 0.5029
# Epoch 4/10
# 66/65 [==============================] - 76s 1s/step - loss: 0.1570 - accuracy: 0.9350 - val_loss: 0.2025 - val_accuracy: 0.9293
# val_kappa: 0.5005
# Epoch 5/10
# 66/65 [==============================] - 75s 1s/step - loss: 0.1561 - accuracy: 0.9388 - val_loss: 0.1796 - val_accuracy: 0.9318
# val_kappa: 0.5524
# Epoch 6/10
# 66/65 [==============================] - 75s 1s/step - loss: 0.1407 - accuracy: 0.9411 - val_loss: 0.2585 - val_accuracy: 0.9216
# val_kappa: 0.4070
# Epoch 7/10
# 66/65 [==============================] - 75s 1s/step - loss: 0.1296 - accuracy: 0.9499 - val_loss: 0.1843 - val_accuracy: 0.9310
# val_kappa: 0.5883
# Validation Kappa has improved. Saving model.
# Epoch 8/10
# 66/65 [==============================] - 75s 1s/step - loss: 0.1409 - accuracy: 0.9426 - val_loss: 0.2583 - val_accuracy: 0.9194
# val_kappa: 0.3636
# Epoch 9/10
# 66/65 [==============================] - 76s 1s/step - loss: 0.1256 - accuracy: 0.9502 - val_loss: 0.1956 - val_accuracy: 0.9336
# val_kappa: 0.5961
# Validation Kappa has improved. Saving model.
# Epoch 10/10
# 66/65 [==============================] - 75s 1s/step - loss: 0.1198 - accuracy: 0.9512 - val_loss: 0.2214 - val_accuracy: 0.9291
# val_kappa: 0.5025
# ----------------------------------------
# Bucket Nr: 3
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/15
# 66/65 [==============================] - 79s 1s/step - loss: 0.1894 - accuracy: 0.9273 - val_loss: 0.2862 - val_accuracy: 0.9104
# val_kappa: 0.3047
# Epoch 2/15
# 66/65 [==============================] - 75s 1s/step - loss: 0.1719 - accuracy: 0.9306 - val_loss: 0.2190 - val_accuracy: 0.9230
# val_kappa: 0.4681
# Epoch 3/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1629 - accuracy: 0.9329 - val_loss: 0.1732 - val_accuracy: 0.9311
# val_kappa: 0.6158
# Validation Kappa has improved. Saving model.
# Epoch 4/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1533 - accuracy: 0.9411 - val_loss: 0.1853 - val_accuracy: 0.9310
# val_kappa: 0.6366
# Validation Kappa has improved. Saving model.
# Epoch 5/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1542 - accuracy: 0.9403 - val_loss: 0.1805 - val_accuracy: 0.9296
# val_kappa: 0.6473
# Validation Kappa has improved. Saving model.
# Epoch 6/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1358 - accuracy: 0.9466 - val_loss: 0.1858 - val_accuracy: 0.9315
# val_kappa: 0.5683
# Epoch 7/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1377 - accuracy: 0.9444 - val_loss: 0.2154 - val_accuracy: 0.9294
# val_kappa: 0.5590
# Epoch 8/15
# 66/65 [==============================] - 75s 1s/step - loss: 0.1251 - accuracy: 0.9499 - val_loss: 0.2426 - val_accuracy: 0.9265
# val_kappa: 0.4853
# Epoch 9/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1173 - accuracy: 0.9543 - val_loss: 0.1908 - val_accuracy: 0.9307
# val_kappa: 0.5701
# Epoch 10/15
# 66/65 [==============================] - 75s 1s/step - loss: 0.1080 - accuracy: 0.9591 - val_loss: 0.2184 - val_accuracy: 0.9319
# val_kappa: 0.5487
# Epoch 11/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1058 - accuracy: 0.9573 - val_loss: 0.2201 - val_accuracy: 0.9249
# val_kappa: 0.5246
# Epoch 12/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1077 - accuracy: 0.9593 - val_loss: 0.2131 - val_accuracy: 0.9165
# val_kappa: 0.5854
# Epoch 13/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1024 - accuracy: 0.9604 - val_loss: 0.2173 - val_accuracy: 0.9260
# val_kappa: 0.5262
# Epoch 14/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.0885 - accuracy: 0.9657 - val_loss: 0.2731 - val_accuracy: 0.9212
# val_kappa: 0.4826
# Epoch 15/15
# 66/65 [==============================] - 75s 1s/step - loss: 0.0887 - accuracy: 0.9672 - val_loss: 0.3142 - val_accuracy: 0.8941
# val_kappa: 0.4618
# ----------------------------------------
# Bucket Nr: 4
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/15
# 66/65 [==============================] - 80s 1s/step - loss: 0.2004 - accuracy: 0.9258 - val_loss: 0.2015 - val_accuracy: 0.9262
# val_kappa: 0.5343
# Epoch 2/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1663 - accuracy: 0.9357 - val_loss: 0.2245 - val_accuracy: 0.9320
# val_kappa: 0.5312
# Epoch 3/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1456 - accuracy: 0.9411 - val_loss: 0.3226 - val_accuracy: 0.9239
# val_kappa: 0.4371
# Epoch 4/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1550 - accuracy: 0.9390 - val_loss: 0.1958 - val_accuracy: 0.9352
# val_kappa: 0.5799
# Epoch 5/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1401 - accuracy: 0.9454 - val_loss: 0.1904 - val_accuracy: 0.9359
# val_kappa: 0.5837
# Epoch 6/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1297 - accuracy: 0.9538 - val_loss: 0.2951 - val_accuracy: 0.9253
# val_kappa: 0.4803
# Epoch 7/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1295 - accuracy: 0.9479 - val_loss: 0.2122 - val_accuracy: 0.9094
# val_kappa: 0.5415
# Epoch 8/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1211 - accuracy: 0.9510 - val_loss: 0.2178 - val_accuracy: 0.9289
# val_kappa: 0.5519
# Epoch 9/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1104 - accuracy: 0.9553 - val_loss: 0.2052 - val_accuracy: 0.9313
# val_kappa: 0.5489
# Epoch 10/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.1121 - accuracy: 0.9563 - val_loss: 0.3866 - val_accuracy: 0.9207
# val_kappa: 0.3936
# Epoch 11/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.0993 - accuracy: 0.9588 - val_loss: 0.2482 - val_accuracy: 0.9306
# val_kappa: 0.5229
# Epoch 12/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.0934 - accuracy: 0.9642 - val_loss: 0.3460 - val_accuracy: 0.9271
# val_kappa: 0.4806
# Epoch 13/15
# 66/65 [==============================] - 75s 1s/step - loss: 0.0964 - accuracy: 0.9632 - val_loss: 0.2787 - val_accuracy: 0.9275
# val_kappa: 0.5042
# Epoch 14/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.0849 - accuracy: 0.9672 - val_loss: 0.2754 - val_accuracy: 0.9309
# val_kappa: 0.5370
# Epoch 15/15
# 66/65 [==============================] - 76s 1s/step - loss: 0.0779 - accuracy: 0.9698 - val_loss: 0.2526 - val_accuracy: 0.9340
# val_kappa: 0.5744
# ----------------------------------------
# Bucket Nr: 5
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/20
# 66/65 [==============================] - 79s 1s/step - loss: 0.2116 - accuracy: 0.9210 - val_loss: 0.1934 - val_accuracy: 0.9296
# val_kappa: 0.5832
# Epoch 2/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1589 - accuracy: 0.9339 - val_loss: 0.2075 - val_accuracy: 0.9336
# val_kappa: 0.5869
# Epoch 3/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.1445 - accuracy: 0.9433 - val_loss: 0.1758 - val_accuracy: 0.9302
# val_kappa: 0.5972
# Epoch 4/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1329 - accuracy: 0.9461 - val_loss: 0.2080 - val_accuracy: 0.9293
# val_kappa: 0.5383
# Epoch 5/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1249 - accuracy: 0.9505 - val_loss: 0.2749 - val_accuracy: 0.9296
# val_kappa: 0.5115
# Epoch 6/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1180 - accuracy: 0.9563 - val_loss: 0.2180 - val_accuracy: 0.9307
# val_kappa: 0.5441
# Epoch 7/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.1075 - accuracy: 0.9583 - val_loss: 0.2443 - val_accuracy: 0.9318
# val_kappa: 0.5511
# Epoch 8/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.0986 - accuracy: 0.9604 - val_loss: 0.2583 - val_accuracy: 0.8924
# val_kappa: 0.4943
# Epoch 9/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.0859 - accuracy: 0.9639 - val_loss: 0.2198 - val_accuracy: 0.9207
# val_kappa: 0.5921
# Epoch 10/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0958 - accuracy: 0.9606 - val_loss: 0.2802 - val_accuracy: 0.9254
# val_kappa: 0.4995
# Epoch 11/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0919 - accuracy: 0.9637 - val_loss: 0.4037 - val_accuracy: 0.9261
# val_kappa: 0.5043
# Epoch 12/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0767 - accuracy: 0.9723 - val_loss: 0.2719 - val_accuracy: 0.9327
# val_kappa: 0.5933
# Epoch 13/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.0773 - accuracy: 0.9690 - val_loss: 0.2822 - val_accuracy: 0.8944
# val_kappa: 0.4720
# Epoch 14/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0727 - accuracy: 0.9710 - val_loss: 0.2493 - val_accuracy: 0.9240
# val_kappa: 0.5810
# Epoch 15/20
# 66/65 [==============================] - 75s 1s/step - loss: 0.0657 - accuracy: 0.9754 - val_loss: 0.3166 - val_accuracy: 0.9304
# val_kappa: 0.5667
# Epoch 16/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0628 - accuracy: 0.9764 - val_loss: 0.3250 - val_accuracy: 0.9251
# val_kappa: 0.5051
# Epoch 17/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0775 - accuracy: 0.9695 - val_loss: 0.2750 - val_accuracy: 0.9232
# val_kappa: 0.5049
# Epoch 18/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0609 - accuracy: 0.9766 - val_loss: 0.2946 - val_accuracy: 0.9170
# val_kappa: 0.5203
# Epoch 19/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0584 - accuracy: 0.9774 - val_loss: 0.4378 - val_accuracy: 0.8683
# val_kappa: 0.3869
# Epoch 20/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0413 - accuracy: 0.9850 - val_loss: 0.3338 - val_accuracy: 0.9271
# val_kappa: 0.5260
# ----------------------------------------
# Bucket Nr: 6
# HBox(children=(FloatProgress(value=0.0, max=1312.0), HTML(value='')))
# Epoch 1/20
# 66/65 [==============================] - 81s 1s/step - loss: 0.2321 - accuracy: 0.9225 - val_loss: 0.2280 - val_accuracy: 0.9138
# val_kappa: 0.5471
# Epoch 2/20
# 66/65 [==============================] - 77s 1s/step - loss: 0.1592 - accuracy: 0.9362 - val_loss: 0.1764 - val_accuracy: 0.9262
# val_kappa: 0.6256
# Epoch 3/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1428 - accuracy: 0.9426 - val_loss: 0.2023 - val_accuracy: 0.9382
# val_kappa: 0.6150
# Epoch 4/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1312 - accuracy: 0.9464 - val_loss: 0.2053 - val_accuracy: 0.9384
# val_kappa: 0.6097
# Epoch 5/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1248 - accuracy: 0.9517 - val_loss: 0.1941 - val_accuracy: 0.9345
# val_kappa: 0.5638
# Epoch 6/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1253 - accuracy: 0.9499 - val_loss: 0.2070 - val_accuracy: 0.9341
# val_kappa: 0.5784
# Epoch 7/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1158 - accuracy: 0.9538 - val_loss: 0.1831 - val_accuracy: 0.9327
# val_kappa: 0.6138
# Epoch 8/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.1029 - accuracy: 0.9571 - val_loss: 0.2394 - val_accuracy: 0.9370
# val_kappa: 0.6172
# Epoch 9/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0970 - accuracy: 0.9627 - val_loss: 0.2332 - val_accuracy: 0.9305
# val_kappa: 0.5542
# Epoch 10/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0885 - accuracy: 0.9642 - val_loss: 0.2144 - val_accuracy: 0.9330
# val_kappa: 0.6113
# Epoch 11/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0936 - accuracy: 0.9616 - val_loss: 0.2906 - val_accuracy: 0.8806
# val_kappa: 0.5077
# Epoch 12/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0814 - accuracy: 0.9654 - val_loss: 0.3101 - val_accuracy: 0.9341
# val_kappa: 0.6006
# Epoch 13/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0794 - accuracy: 0.9667 - val_loss: 0.4731 - val_accuracy: 0.9250
# val_kappa: 0.4593
# Epoch 14/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0761 - accuracy: 0.9693 - val_loss: 0.2482 - val_accuracy: 0.9078
# val_kappa: 0.5622
# Epoch 15/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0703 - accuracy: 0.9743 - val_loss: 0.2518 - val_accuracy: 0.9336
# val_kappa: 0.6300
# Epoch 16/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0595 - accuracy: 0.9764 - val_loss: 0.2362 - val_accuracy: 0.9257
# val_kappa: 0.6338
# Epoch 17/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0510 - accuracy: 0.9787 - val_loss: 0.2690 - val_accuracy: 0.9305
# val_kappa: 0.6196
# Epoch 18/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0486 - accuracy: 0.9797 - val_loss: 0.2515 - val_accuracy: 0.9291
# val_kappa: 0.6065
# Epoch 19/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0495 - accuracy: 0.9802 - val_loss: 0.5088 - val_accuracy: 0.9294
# val_kappa: 0.5578
# Epoch 20/20
# 66/65 [==============================] - 76s 1s/step - loss: 0.0418 - accuracy: 0.9845 - val_loss: 0.3145 - val_accuracy: 0.9324
# val_kappa: 0.6339
# ----------------------------------------
# Bucket Nr: 7
# HBox(children=(FloatProgress(value=0.0, max=1316.0), HTML(value='')))
# Epoch 1/30
# 66/65 [==============================] - 87s 1s/step - loss: 0.2444 - accuracy: 0.9233 - val_loss: 0.2900 - val_accuracy: 0.9285
# val_kappa: 0.5387
# Epoch 2/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.1743 - accuracy: 0.9306 - val_loss: 0.1936 - val_accuracy: 0.9312
# val_kappa: 0.5863
# Epoch 3/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.1489 - accuracy: 0.9405 - val_loss: 0.1673 - val_accuracy: 0.9373
# val_kappa: 0.6455
# Epoch 4/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.1379 - accuracy: 0.9440 - val_loss: 0.2301 - val_accuracy: 0.8943
# val_kappa: 0.5351
# Epoch 5/30
# 66/65 [==============================] - 77s 1s/step - loss: 0.1311 - accuracy: 0.9488 - val_loss: 0.1865 - val_accuracy: 0.9334
# val_kappa: 0.6345
# Epoch 6/30
# 66/65 [==============================] - 77s 1s/step - loss: 0.1244 - accuracy: 0.9481 - val_loss: 0.1893 - val_accuracy: 0.9358
# val_kappa: 0.6375
# Epoch 7/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.1105 - accuracy: 0.9585 - val_loss: 0.2355 - val_accuracy: 0.9022
# val_kappa: 0.5001
# Epoch 8/30
# 66/65 [==============================] - 77s 1s/step - loss: 0.1079 - accuracy: 0.9554 - val_loss: 0.2259 - val_accuracy: 0.9112
# val_kappa: 0.5820
# Epoch 9/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0970 - accuracy: 0.9623 - val_loss: 0.1980 - val_accuracy: 0.9343
# val_kappa: 0.6155
# Epoch 10/30
# 66/65 [==============================] - 78s 1s/step - loss: 0.0960 - accuracy: 0.9630 - val_loss: 0.1907 - val_accuracy: 0.9321
# val_kappa: 0.6368
# Epoch 11/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0871 - accuracy: 0.9678 - val_loss: 0.2649 - val_accuracy: 0.9327
# val_kappa: 0.5825
# Epoch 12/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0842 - accuracy: 0.9661 - val_loss: 0.2766 - val_accuracy: 0.9271
# val_kappa: 0.5581
# Epoch 13/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0721 - accuracy: 0.9729 - val_loss: 0.2358 - val_accuracy: 0.9229
# val_kappa: 0.6213
# Epoch 14/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0751 - accuracy: 0.9709 - val_loss: 0.2338 - val_accuracy: 0.9313
# val_kappa: 0.6315
# Epoch 15/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0595 - accuracy: 0.9754 - val_loss: 0.3198 - val_accuracy: 0.8876
# val_kappa: 0.4844
# Epoch 16/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0511 - accuracy: 0.9807 - val_loss: 0.3146 - val_accuracy: 0.9332
# val_kappa: 0.6206
# Epoch 17/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0549 - accuracy: 0.9785 - val_loss: 0.3897 - val_accuracy: 0.8662
# val_kappa: 0.4783
# Epoch 18/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0586 - accuracy: 0.9780 - val_loss: 0.3287 - val_accuracy: 0.8748
# val_kappa: 0.4452
# Epoch 19/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0500 - accuracy: 0.9815 - val_loss: 0.2599 - val_accuracy: 0.9127
# val_kappa: 0.5540
# Epoch 20/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0454 - accuracy: 0.9833 - val_loss: 0.3141 - val_accuracy: 0.8922
# val_kappa: 0.5503
# Epoch 21/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0491 - accuracy: 0.9818 - val_loss: 0.3195 - val_accuracy: 0.9278
# val_kappa: 0.5541
# Epoch 22/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0495 - accuracy: 0.9820 - val_loss: 0.2792 - val_accuracy: 0.9276
# val_kappa: 0.5595
# Epoch 23/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0368 - accuracy: 0.9868 - val_loss: 0.2959 - val_accuracy: 0.9317
# val_kappa: 0.5952
# Epoch 24/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0393 - accuracy: 0.9853 - val_loss: 0.3269 - val_accuracy: 0.9310
# val_kappa: 0.5770
# Epoch 25/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0293 - accuracy: 0.9899 - val_loss: 0.2973 - val_accuracy: 0.9332
# val_kappa: 0.6433
# Epoch 26/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.3380 - val_accuracy: 0.9358
# val_kappa: 0.6402
# Epoch 27/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.2915 - val_accuracy: 0.9295
# val_kappa: 0.6082
# Epoch 28/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0474 - accuracy: 0.9802 - val_loss: 0.2959 - val_accuracy: 0.9234
# val_kappa: 0.5685
# Epoch 29/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0321 - accuracy: 0.9873 - val_loss: 0.3237 - val_accuracy: 0.9210
# val_kappa: 0.6182
# Epoch 30/30
# 66/65 [==============================] - 76s 1s/step - loss: 0.0328 - accuracy: 0.9873 - val_loss: 0.4333 - val_accuracy: 0.9268
# val_kappa: 0.5127
# ----------------------------------------

# %%
results = results.iloc[1:]
results['kappa'] = kappa_metrics.val_kappas
results = results.reset_index()
results = results.rename(index=str, columns={"index": "epoch"})
results
# Out:
#      epoch  val_loss  val_accuracy      loss  accuracy  bucket     kappa
# 0        0  1.126017      0.376667  0.472030  0.792937     0.0  0.129473
# 1        1  0.340009      0.896889  0.256535  0.896850     0.0  0.424052
# 2        2  0.240762      0.916222  0.233606  0.901423     0.0  0.510322
# 3        3  0.242744      0.889778  0.209332  0.915142     0.0  0.434851
# 4        4  0.220441      0.914889  0.205149  0.915650     0.0  0.347541
# ..     ...       ...           ...       ...       ...     ...       ...
# 115     25  0.337957      0.935778  0.038454  0.986322     7.0  0.640230
# 116     26  0.291477      0.929481  0.030820  0.988855     7.0  0.608170
# 117     27  0.295870      0.923407  0.047405  0.980243     7.0  0.568472
# 118     28  0.323692      0.921037  0.032166  0.987336     7.0  0.618219
# 119     29  0.433251      0.926815  0.032898  0.987335     7.0  0.512712
#
# [120 rows x 7 columns]

# %%
results[['loss', 'val_loss']].plot()
results[['accuracy', 'val_accuracy']].plot()
results[['kappa']].plot()
results.to_csv('results_3_all.csv',index=False)

# %% [markdown]
# # Find best threshold

# %%
model.load_weights('denseNet_3_all.h5')
y_val_pred = model.predict(x_val)

def compute_score_inv(threshold):
    y1 = y_val_pred > threshold
    y1 = y1.astype(int).sum(axis=1) - 1
    y2 = y_val.sum(axis=1) - 1
    score = cohen_kappa_score(y1, y2, weights='quadratic')
    
    return 1 - score

simplex = scipy.optimize.minimize(
    compute_score_inv, 0.5, method='nelder-mead'
)

best_threshold = simplex['x'][0]

y1 = y_val_pred > best_threshold
y1 = y1.astype(int).sum(axis=1) - 1
y2 = y_val.sum(axis=1) - 1
score = cohen_kappa_score(y1, y2, weights='quadratic')
print('Threshold: {}'.format(best_threshold))
print('Validation QWK score with best_threshold: {}'.format(score))

y1 = y_val_pred > .5
y1 = y1.astype(int).sum(axis=1) - 1
score = cohen_kappa_score(y1, y2, weights='quadratic')
print('Validation QWK score with .5 threshold: {}'.format(score))
# Out:
# Threshold: 0.5359375000000001
# Validation QWK score with best_threshold: 0.6493796450556493
# Validation QWK score with .5 threshold: 0.6472545432308368

# %%
# %mv denseNet_3_all.h5 results_3_all.csv ../

# %%
y_best = y_val_pred > best_threshold
y_best  = y_best .astype(int).sum(axis=1) - 1
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
print(confusion_matrix(y_best, y2))
print('Classification Report')
target_names = ['No DR', 'Moderate','Severe']
print(classification_report(y_best, y2, target_names=target_names))
# Out:
# Confusion Matrix
# [[3084  499   17]
#  [ 228  371   54]
#  [   6   95  146]]
# Classification Report
#               precision    recall  f1-score   support
#
#        No DR       0.93      0.86      0.89      3600
#     Moderate       0.38      0.57      0.46       653
#       Severe       0.67      0.59      0.63       247
#
#     accuracy                           0.80      4500
#    macro avg       0.66      0.67      0.66      4500
# weighted avg       0.84      0.80      0.81      4500

# %%
# score = model.evaluate(x_val, Y, verbose=0)
# print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))

# %% [markdown]
# # Inference Kernel
#
# https://www.kaggle.com/raimonds1993/aptos19-densenet-trained-with-old-and-new-data
